# %%
from surface_code import GenerateSurfaceCode
import stim

# %%
c = GenerateSurfaceCode(5, 10).get_circuit()

# %%
c.diagram("detslice-svg", tick=range(0,10))
# Out:
# <svg viewBox="0 0 1110.58 826.477" xmlns="http://www.w3.org/2000/svg">
# <g id="slice:1:3.5_1.5:3">
# <path d="M981.442,38.6274 C995.018 29.5764,995.018 29.5764,1004.07 16 L1026.7,38.6274 C1013.12 47.6784,1013.12 47.6784,1004.07 61.2548 C990.493 70.3058,990.493 70.3058,981.442 83.8822 L958.814,61.2548 C972.391 52.2039,972.391 52.2039,981.442 38.6274" stroke="none" fill-opacity="0.75" fill="#4DA6FF"/>
# <path d="M981.442,38.6274 C995.018 29.5764,995.018 29.5764,1004.07 16 L1026.7,38.6274 C1013.12 47.6784,1013.12 47.6784,1004.07 61.2548 C990.493 70.3058,990.493 70.3058,981.442 83.8822 L958.814,61.2548 C972.391 52.2039,972.391 52.2039,981.442 38.6274" stroke="black" fill="none"/>
# </g>
# <g id="slice:4:2.5_2.5:3">
# ...
